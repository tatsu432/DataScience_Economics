# %%
import csv
def read_csv(filename):
    filename += ".csv"
    filename = "CSV/" + filename 
    lists = []
    with open(filename, encoding="UTF-8") as f:
        for list in csv.reader(f):
            list[1] = float(list[1])
            list[2] = float(list[2])
            lists.append(list)
    return lists

# %%
lists_IKEA = read_csv("IKEA")
lists_COSTCO = read_csv("COSTCO")
lists_LALAPORT = read_csv("LALAPORT")
lists_NITORI = read_csv("NITORI")
lists_DECOHOME = read_csv("DECOHOME")
lists_station = read_csv("station")
lists_all_stations = read_csv("all_stations")
lists_IC = read_csv("IC")

# %%
import folium
from folium.features import CustomIcon

def create_icon(path):
    return CustomIcon(
    icon_image = path,
    icon_size = (500, 500),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
    )

icon_ikea = create_icon('icons/ikea.png')
icon_costco = create_icon('icons/costco.png')

icon_hub = create_icon('icons/hub.png')
icon_station = create_icon('icons/station.png')
icon_ic = create_icon('icons/ic.png')

icon_lalaport = create_icon('icons/lalaport.png')
icon_nitori = create_icon('icons/nitori.png')
icon_decohome = create_icon('icons/decohome.png')

icon_ikea = CustomIcon(
    icon_image = 'icons/ikea.png',
    icon_size = (50, 50),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
)

# %%
# define the function to visualize the map
import folium

def create_icon(path):
    return CustomIcon(
    icon_image = path,
    icon_size = (30, 30),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
    )
            
def show_map(latitude, longitude, icon_others, lists_others, map):
    
    
    # loop for list IKEA
    for i in range(len(lists_IKEA)): 
        icon_ikea = create_icon('icons/ikea.png')     
           
        name = lists_IKEA[i][0]
        latitude = lists_IKEA[i][1]
        longitude = lists_IKEA[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_ikea
        ).add_to(map)

    # loop for list COSTCO
    for i in range(len(lists_COSTCO)): 
        icon_costco = create_icon('icons/costco.png')
                
        name = lists_COSTCO[i][0]
        latitude = lists_COSTCO[i][1]
        longitude = lists_COSTCO[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_costco
        ).add_to(map)

    # loop for list others
    for i in range(len(lists_others)): 
        icon_hub = create_icon('icons/hub1.png')
        icon_station = create_icon('icons/station.png')
        icon_ic = create_icon('icons/ic.png')

        icon_lalaport = create_icon('icons/lalaport.png')
        icon_nitori = create_icon('icons/nitori.png')
        icon_decohome = create_icon('icons/decohome.png')
        
        if (lists_others == lists_station):
            icon_others = icon_hub
        elif (lists_others == lists_all_stations):
            icon_others = icon_station
        elif (lists_others == lists_IC):
            icon_others = icon_ic
        elif (lists_others == lists_LALAPORT):
            icon_others = icon_lalaport
        elif (lists_others == lists_NITORI):
            icon_others = icon_nitori
        elif (lists_others == lists_DECOHOME):
            icon_others = icon_decohome
        
        name = lists_others[i][0]
        latitude = lists_others[i][1]
        longitude = lists_others[i][2]
        
        # add circle on the map
        folium.Marker(
            radius=5000,
            location=[latitude, longitude],
            popup=name,
            icon = icon_others
        ).add_to(map)
        


# define the function for visualization of the hub station
def show_map_hub_station(latitude, longitude, map):
    show_map(latitude, longitude, icon_hub, lists_station, map)

# define the function for visualization of the LALAPORT
def show_map_lalaport(latitude, longitude, map):
    show_map(latitude, longitude, icon_lalaport, lists_LALAPORT, map)

# define the function for visualization of the NITORI
def show_map_nitori(latitude, longitude, map):
    show_map(latitude, longitude, icon_nitori, lists_NITORI, map)

# define the function for visualization of the hub DECOHOME
def show_map_decohome(latitude, longitude, map):
    show_map(latitude, longitude, icon_decohome, lists_DECOHOME, map)

# %%
# define the function to visualize the map
import folium
from geopy.distance import geodesic

def create_icon(path):
    return CustomIcon(
    icon_image = path,
    icon_size = (30, 30),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
    )
            
def show_map_truncate(latitude, longitude, icon_others, lists_others, map):
    
    lat_long = (latitude, longitude)
    
    # loop for list IKEA
    for i in range(len(lists_IKEA)): 
        icon_ikea = create_icon('icons/ikea.png')     
           
        name = lists_IKEA[i][0]
        latitude = lists_IKEA[i][1]
        longitude = lists_IKEA[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_ikea
        ).add_to(map)

    # loop for list COSTCO
    for i in range(len(lists_COSTCO)): 
        icon_costco = create_icon('icons/costco.png')
                
        name = lists_COSTCO[i][0]
        latitude = lists_COSTCO[i][1]
        longitude = lists_COSTCO[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_costco
        ).add_to(map)

    # loop for list others
    for i in range(len(lists_others)): 
        icon_station = create_icon('icons/station.png')
        icon_ic = create_icon('icons/ic.png')
        
        if (lists_others == lists_all_stations):
            icon_others = icon_station
        elif (lists_others == lists_IC):
            icon_others = icon_ic
        
        name = lists_others[i][0]
        latitude2 = lists_others[i][1]
        longitude2 = lists_others[i][2]
        lat_long2 = (latitude2, longitude2)
        
        dist = geodesic(lat_long, lat_long2).km
        if(dist <= geodesic(300).km): 
            # add circle on the map
            folium.Marker(
                location=[latitude2, longitude2],
                popup=name,
                icon = icon_others
            ).add_to(map)
        


# define the function for visualization of the all station
def show_map_all_station(latitude, longitude, map):
    show_map_truncate(latitude, longitude, icon_station, lists_all_stations, map)

# define the function for visualization of the IC
def show_map_ic(latitude, longitude, map):
    show_map_truncate(latitude, longitude, icon_ic, lists_IC, map)

# %%
# Show Tokyo map (NITORI)
# define the map
lists_lat_long = [35.660404695921, 139.69962571292]
map = folium.Map(location=lists_lat_long, 
                tiles = "Stamen Terrain", 
                zoom_start=9)

show_map_nitori(lists_lat_long[0], lists_lat_long[1],  map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd5251005aa0661b657cecf7eec960b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd5251005aa0661b657cecf7eec960b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_dd5251005aa0661b657cecf7eec960b6 = L.map(
#                 &quot;map_dd5251005aa0661b657cecf7eec960b6&quot;,
#                 {
#                     center: [35.660404695921, 139.69962571292],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10f835767399afcf5de8ba43658a5c4a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dd5251005aa0661b657cecf7eec960b6);
#
#
#             var marker_091a778302243b69316dbd5d97b92b3d = L.marker(
#                 [38.225443683680965, 140.88619132558006],
#                 {}
#             ).addTo(map_dd5251005aa0661b657cecf7eec960b6);
#
#
#         var custom_icon_06ca668a5eb51ac8f7d6ad37d19f9653 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_091a778302243b69316dbd5d97b92b3d.setIcon(custom_icon_06ca668a5eb51ac8f7d6ad37d19f9653);
#
#
#         var popup_8c43f49a9af56b09ec345c5d3cce1127 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7baaaaedd83677f8ed9203ca46fb8731 = $(`&lt;div id=&quot;html_7baaaaedd83677f8ed9203ca46fb8731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 仙台&lt;/div&gt;`)[0];
#             popup_8c43f49a9af56b09ec345c5d3cce1127.setContent(html_7baaaaedd83677f8ed9203ca46fb8731);
#
#
#         marker_091a778302243b69316dbd5d97b92b3d.bindPopup(popup_8c43f49a9af56b09ec345c5d3cce1127)
#         ;
#
#
#
#
#             var marker_5053b3cb345d146b0d175d403f14b51f = L.marker(
#                 [35.85624087928599, 139.87055303188004],
#                 {}
#             ).addTo(map_dd5251005aa0661b657cecf7eec960b6);
#
#
#         var custom_icon_49fdedbb26f1c4f0c78cbec4161d6f37 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_5053b3cb345d146b0d175d403f14b51f.setIcon(custom_icon_49fdedbb26f1c4f0c78cbec4161d6f37);
#
#
#         var popup_e666ed31694bcf3cba6c04316de5d5a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e9b7b4f5cc3fe484cb7bf8ab9e24201d = $(`&lt;div id=&quot;html_e9b7b4f5cc3fe484cb7bf8ab9e24201d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 新三郷&lt;/div&gt;`)[0];
#             popup_e666ed31694bcf3cba6c04316de5d5a6.setContent(html_e9b7b4f5cc3fe484cb7bf8ab9e24201d);
#
#
#         marker_5053b3cb345d146b0d175d403f14b51f.bindPopup(popup_e666ed31694bcf3cba6c04316de5d5a6)
#         ;
#
#
#
#
#             var marker_e39201e580a3a3d80b97eb1ea64cfbbb = L.marker(
#                 [35.681556817882, 139.99198855709005],
#                 {}
#             ).addTo(map_dd5251005aa0661b657cecf7eec960b6);
#
#
#         var custom_icon_215de9153f5af5666982c18780a7cdc9 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_e39201e580a3a3d80b97eb1ea64cfbbb.setIcon(custom_icon_215de9153f5af5666982c18780a7cdc9);
#
#
#         var popup_cf4434603c5eee7535fe0fc21970003c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6dd26954dd6c0448f3212aa9cccd3d93 = $(`&lt;div id=&quot;html_6dd26954dd6c0448f3212aa9cccd3d93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA  Tokyo-Bay&lt;/div&gt;`)[0];
#             popup_cf4434603c5eee7535fe0fc21970003c.setContent(html_6dd26954dd6c0448f3212aa9cccd3d93);
#
#
#         marker_e39201e580a3a3d80b97eb1ea64cfbbb.bindPopup(popup_cf4434603c5eee7535fe0fc21970003c)
#         ;
#
#
#
#
#             var marker_8385116788ea23961ae005fe1a74a9d3 = L.marker(
#                 [35.706808311052995, 139.41189273079],
#                 {}
#             ).addTo(map_dd5251005aa0661b657cecf7eec960b6);
#
#
#         var custom_icon_089bedd06d238faafed3083a30c67dc0 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_8385116788ea23961ae005fe1a74a9d3.setIcon(custom_icon_089bedd06d238faafed3083a30c67dc0);
#
#
#         var popup_d75bbe3a563ebcad9d7a90ed29069547 = L.popup({&quot;maxWidth&

# %%
map.save("HTML/NITORI_Tokyo.html")

# %%
# Show Osaka and Kobe map (NITORI)
# define the map
lists_lat_long = [34.74185761949499, 135.44375197245995]
map = folium.Map(location=lists_lat_long, 
                tiles = "Stamen Terrain", 
                zoom_start=9)

show_map_nitori(lists_lat_long[0], lists_lat_long[1],  map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21247430f340cc202666f29c5752fcbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21247430f340cc202666f29c5752fcbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_21247430f340cc202666f29c5752fcbb = L.map(
#                 &quot;map_21247430f340cc202666f29c5752fcbb&quot;,
#                 {
#                     center: [34.74185761949499, 135.44375197245995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4a0f3ac25da98479e26390c19287648 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21247430f340cc202666f29c5752fcbb);
#
#
#             var marker_56d36ebe8c82302e0e2e63f9dd7c4cdc = L.marker(
#                 [38.225443683680965, 140.88619132558006],
#                 {}
#             ).addTo(map_21247430f340cc202666f29c5752fcbb);
#
#
#         var custom_icon_657571798d95b1d747b1b081f1cad0c5 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_56d36ebe8c82302e0e2e63f9dd7c4cdc.setIcon(custom_icon_657571798d95b1d747b1b081f1cad0c5);
#
#
#         var popup_469d2dc65168c61b2dcbca88a0630906 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3fb7a9ef18996e4c268ff24c37d3d043 = $(`&lt;div id=&quot;html_3fb7a9ef18996e4c268ff24c37d3d043&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 仙台&lt;/div&gt;`)[0];
#             popup_469d2dc65168c61b2dcbca88a0630906.setContent(html_3fb7a9ef18996e4c268ff24c37d3d043);
#
#
#         marker_56d36ebe8c82302e0e2e63f9dd7c4cdc.bindPopup(popup_469d2dc65168c61b2dcbca88a0630906)
#         ;
#
#
#
#
#             var marker_b029fbf9ff59b991fd9d0fb49a8d08e4 = L.marker(
#                 [35.85624087928599, 139.87055303188004],
#                 {}
#             ).addTo(map_21247430f340cc202666f29c5752fcbb);
#
#
#         var custom_icon_5765fcc34ee9ea106cd942f6bd9bbbc3 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_b029fbf9ff59b991fd9d0fb49a8d08e4.setIcon(custom_icon_5765fcc34ee9ea106cd942f6bd9bbbc3);
#
#
#         var popup_3f45df8a63b3397650cc15561941d930 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6b365117eeba523a8427400dc4ad49bb = $(`&lt;div id=&quot;html_6b365117eeba523a8427400dc4ad49bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 新三郷&lt;/div&gt;`)[0];
#             popup_3f45df8a63b3397650cc15561941d930.setContent(html_6b365117eeba523a8427400dc4ad49bb);
#
#
#         marker_b029fbf9ff59b991fd9d0fb49a8d08e4.bindPopup(popup_3f45df8a63b3397650cc15561941d930)
#         ;
#
#
#
#
#             var marker_1d988e2399bd2bb680b9c3a3edf92749 = L.marker(
#                 [35.681556817882, 139.99198855709005],
#                 {}
#             ).addTo(map_21247430f340cc202666f29c5752fcbb);
#
#
#         var custom_icon_8345892b69ff417fdee55c4da9d96108 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_1d988e2399bd2bb680b9c3a3edf92749.setIcon(custom_icon_8345892b69ff417fdee55c4da9d96108);
#
#
#         var popup_4f2a3a6332786b9997a144fc1e7b79b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_46446b801eb393a1ca14de5e00580a4c = $(`&lt;div id=&quot;html_46446b801eb393a1ca14de5e00580a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA  Tokyo-Bay&lt;/div&gt;`)[0];
#             popup_4f2a3a6332786b9997a144fc1e7b79b4.setContent(html_46446b801eb393a1ca14de5e00580a4c);
#
#
#         marker_1d988e2399bd2bb680b9c3a3edf92749.bindPopup(popup_4f2a3a6332786b9997a144fc1e7b79b4)
#         ;
#
#
#
#
#             var marker_2b673bb6a2b03707c900ce38eb81e4a5 = L.marker(
#                 [35.706808311052995, 139.41189273079],
#                 {}
#             ).addTo(map_21247430f340cc202666f29c5752fcbb);
#
#
#         var custom_icon_d2c756bced90c9d7d5522add2f71863b = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_2b673bb6a2b03707c900ce38eb81e4a5.setIcon(custom_icon_d2c756bced90c9d7d5522add2f71863b);
#
#
#         var popup_dcfad1d0b7b4a240940335ec9b40382c = L.popup({&quot;maxW

# %%
map.save("HTML/NITORI_Osaka.html")
