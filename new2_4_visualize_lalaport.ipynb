# %%
import csv
def read_csv(filename):
    filename += ".csv"
    filename = "CSV/" + filename 
    lists = []
    with open(filename, encoding="UTF-8") as f:
        for list in csv.reader(f):
            list[1] = float(list[1])
            list[2] = float(list[2])
            lists.append(list)
    return lists

# %%
lists_IKEA = read_csv("IKEA")
lists_COSTCO = read_csv("COSTCO")
lists_LALAPORT = read_csv("LALAPORT")
lists_NITORI = read_csv("NITORI")
lists_DECOHOME = read_csv("DECOHOME")
lists_station = read_csv("station")
lists_all_stations = read_csv("all_stations")
lists_IC = read_csv("IC")

# %%
import folium
from folium.features import CustomIcon

def create_icon(path):
    return CustomIcon(
    icon_image = path,
    icon_size = (500, 500),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
    )

icon_ikea = create_icon('icons/ikea.png')
icon_costco = create_icon('icons/costco.png')

icon_hub = create_icon('icons/hub.png')
icon_station = create_icon('icons/station.png')
icon_ic = create_icon('icons/ic.png')

icon_lalaport = create_icon('icons/lalaport.png')
icon_nitori = create_icon('icons/nitori.png')
icon_decohome = create_icon('icons/decohome.png')

icon_ikea = CustomIcon(
    icon_image = 'icons/ikea.png',
    icon_size = (50, 50),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
)

# %%
# define the function to visualize the map
import folium

def create_icon(path):
    return CustomIcon(
    icon_image = path,
    icon_size = (30, 30),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
    )
            
def show_map(latitude, longitude, icon_others, lists_others, map):
    
    
    # loop for list IKEA
    for i in range(len(lists_IKEA)): 
        icon_ikea = create_icon('icons/ikea.png')     
           
        name = lists_IKEA[i][0]
        latitude = lists_IKEA[i][1]
        longitude = lists_IKEA[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_ikea
        ).add_to(map)

    # loop for list COSTCO
    for i in range(len(lists_COSTCO)): 
        icon_costco = create_icon('icons/costco.png')
                
        name = lists_COSTCO[i][0]
        latitude = lists_COSTCO[i][1]
        longitude = lists_COSTCO[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_costco
        ).add_to(map)

    # loop for list others
    for i in range(len(lists_others)): 
        icon_hub = create_icon('icons/hub1.png')
        icon_station = create_icon('icons/station.png')
        icon_ic = create_icon('icons/ic.png')

        icon_lalaport = create_icon('icons/lalaport.png')
        icon_nitori = create_icon('icons/nitori.png')
        icon_decohome = create_icon('icons/decohome.png')
        
        if (lists_others == lists_station):
            icon_others = icon_hub
        elif (lists_others == lists_all_stations):
            icon_others = icon_station
        elif (lists_others == lists_IC):
            icon_others = icon_ic
        elif (lists_others == lists_LALAPORT):
            icon_others = icon_lalaport
        elif (lists_others == lists_NITORI):
            icon_others = icon_nitori
        elif (lists_others == lists_DECOHOME):
            icon_others = icon_decohome
        
        name = lists_others[i][0]
        latitude = lists_others[i][1]
        longitude = lists_others[i][2]
        
        # add circle on the map
        folium.Marker(
            radius=5000,
            location=[latitude, longitude],
            popup=name,
            icon = icon_others
        ).add_to(map)
        


# define the function for visualization of the hub station
def show_map_hub_station(latitude, longitude, map):
    show_map(latitude, longitude, icon_hub, lists_station, map)

# define the function for visualization of the LALAPORT
def show_map_lalaport(latitude, longitude, map):
    show_map(latitude, longitude, icon_lalaport, lists_LALAPORT, map)

# define the function for visualization of the NITORI
def show_map_nitori(latitude, longitude, map):
    show_map(latitude, longitude, icon_nitori, lists_NITORI, map)

# define the function for visualization of the hub DECOHOME
def show_map_decohome(latitude, longitude, map):
    show_map(latitude, longitude, icon_decohome, lists_DECOHOME, map)

# %%
# define the function to visualize the map
import folium
from geopy.distance import geodesic

def create_icon(path):
    return CustomIcon(
    icon_image = path,
    icon_size = (30, 30),
    icon_anchor = (30, 30),
    popup_anchor = (3, 3)
    )
            
def show_map_truncate(latitude, longitude, icon_others, lists_others, map):
    
    lat_long = (latitude, longitude)
    
    # loop for list IKEA
    for i in range(len(lists_IKEA)): 
        icon_ikea = create_icon('icons/ikea.png')     
           
        name = lists_IKEA[i][0]
        latitude = lists_IKEA[i][1]
        longitude = lists_IKEA[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_ikea
        ).add_to(map)

    # loop for list COSTCO
    for i in range(len(lists_COSTCO)): 
        icon_costco = create_icon('icons/costco.png')
                
        name = lists_COSTCO[i][0]
        latitude = lists_COSTCO[i][1]
        longitude = lists_COSTCO[i][2]
        
        # add circle on the map
        folium.Marker(
            location=[latitude, longitude],
            popup=name,
            icon = icon_costco
        ).add_to(map)

    # loop for list others
    for i in range(len(lists_others)): 
        icon_station = create_icon('icons/station.png')
        icon_ic = create_icon('icons/ic.png')
        
        if (lists_others == lists_all_stations):
            icon_others = icon_station
        elif (lists_others == lists_IC):
            icon_others = icon_ic
        
        name = lists_others[i][0]
        latitude2 = lists_others[i][1]
        longitude2 = lists_others[i][2]
        lat_long2 = (latitude2, longitude2)
        
        dist = geodesic(lat_long, lat_long2).km
        if(dist <= geodesic(300).km): 
            # add circle on the map
            folium.Marker(
                location=[latitude2, longitude2],
                popup=name,
                icon = icon_others
            ).add_to(map)
        


# define the function for visualization of the all station
def show_map_all_station(latitude, longitude, map):
    show_map_truncate(latitude, longitude, icon_station, lists_all_stations, map)

# define the function for visualization of the IC
def show_map_ic(latitude, longitude, map):
    show_map_truncate(latitude, longitude, icon_ic, lists_IC, map)

# %%
# Show Tokyo map (LALAPORT)
# define the map
lists_lat_long = [34.74185761949499, 135.44375197245995]
map = folium.Map(location=lists_lat_long, 
                tiles = "Stamen Terrain", 
                zoom_start=9)

show_map_lalaport(lists_lat_long[0], lists_lat_long[1], map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb1fbdd07ee3a1f2c73236510c31accc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb1fbdd07ee3a1f2c73236510c31accc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bb1fbdd07ee3a1f2c73236510c31accc = L.map(
#                 &quot;map_bb1fbdd07ee3a1f2c73236510c31accc&quot;,
#                 {
#                     center: [34.74185761949499, 135.44375197245995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b1a505c1ab19c38adb1b031bc0455e7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb1fbdd07ee3a1f2c73236510c31accc);
#
#
#             var marker_6e0f16f34f6401f14112a13531a47c6a = L.marker(
#                 [38.225443683680965, 140.88619132558006],
#                 {}
#             ).addTo(map_bb1fbdd07ee3a1f2c73236510c31accc);
#
#
#         var custom_icon_b91cb4ee6a65c46e2b1f126360f82551 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_6e0f16f34f6401f14112a13531a47c6a.setIcon(custom_icon_b91cb4ee6a65c46e2b1f126360f82551);
#
#
#         var popup_cf63f3e791a2668ee1c51907b79cc662 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_107010bc20dc656ee8bd37275cc317bf = $(`&lt;div id=&quot;html_107010bc20dc656ee8bd37275cc317bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 仙台&lt;/div&gt;`)[0];
#             popup_cf63f3e791a2668ee1c51907b79cc662.setContent(html_107010bc20dc656ee8bd37275cc317bf);
#
#
#         marker_6e0f16f34f6401f14112a13531a47c6a.bindPopup(popup_cf63f3e791a2668ee1c51907b79cc662)
#         ;
#
#
#
#
#             var marker_08bce9a8b4fc4a57a9d481dbf3b8cd1f = L.marker(
#                 [35.85624087928599, 139.87055303188004],
#                 {}
#             ).addTo(map_bb1fbdd07ee3a1f2c73236510c31accc);
#
#
#         var custom_icon_fd8d84adcf848f2f1127688af5b0651f = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_08bce9a8b4fc4a57a9d481dbf3b8cd1f.setIcon(custom_icon_fd8d84adcf848f2f1127688af5b0651f);
#
#
#         var popup_6257069e37cd32531fa75ffd87b2f84c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5f3e8fc06308ca896f9e54072dbda171 = $(`&lt;div id=&quot;html_5f3e8fc06308ca896f9e54072dbda171&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 新三郷&lt;/div&gt;`)[0];
#             popup_6257069e37cd32531fa75ffd87b2f84c.setContent(html_5f3e8fc06308ca896f9e54072dbda171);
#
#
#         marker_08bce9a8b4fc4a57a9d481dbf3b8cd1f.bindPopup(popup_6257069e37cd32531fa75ffd87b2f84c)
#         ;
#
#
#
#
#             var marker_0879afeb85fd4b2ef5f1e7150f45ef09 = L.marker(
#                 [35.681556817882, 139.99198855709005],
#                 {}
#             ).addTo(map_bb1fbdd07ee3a1f2c73236510c31accc);
#
#
#         var custom_icon_877b0acfe92a1524699c482df1e1715f = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_0879afeb85fd4b2ef5f1e7150f45ef09.setIcon(custom_icon_877b0acfe92a1524699c482df1e1715f);
#
#
#         var popup_e8ec4e0e786dea4c0ccdd41a9110a67d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a455ac14d6f49b73bab4480b79450c82 = $(`&lt;div id=&quot;html_a455ac14d6f49b73bab4480b79450c82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA  Tokyo-Bay&lt;/div&gt;`)[0];
#             popup_e8ec4e0e786dea4c0ccdd41a9110a67d.setContent(html_a455ac14d6f49b73bab4480b79450c82);
#
#
#         marker_0879afeb85fd4b2ef5f1e7150f45ef09.bindPopup(popup_e8ec4e0e786dea4c0ccdd41a9110a67d)
#         ;
#
#
#
#
#             var marker_8bd57183e010c54d38f72ba3b851a8a6 = L.marker(
#                 [35.706808311052995, 139.41189273079],
#                 {}
#             ).addTo(map_bb1fbdd07ee3a1f2c73236510c31accc);
#
#
#         var custom_icon_7fc2d0f487f5b3f2453df71f7a8ae0b4 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_8bd57183e010c54d38f72ba3b851a8a6.setIcon(custom_icon_7fc2d0f487f5b3f2453df71f7a8ae0b4);
#
#
#         var popup_93201a2b455f98c2aa195bf120fb3863 = L.popup({&quot;maxW

# %%
map.save("HTML/LALAPORT_Tokyo.html")

# %%
# Show Osaka and Kobe map (LALAPORT)
# define the map
lists_lat_long = [34.74185761949499, 135.44375197245995]
map = folium.Map(location=lists_lat_long, 
                tiles = "Stamen Terrain", 
                zoom_start=9)

show_map_lalaport(lists_lat_long[0], lists_lat_long[1], map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b151517720b90942985302073cf32159 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b151517720b90942985302073cf32159&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b151517720b90942985302073cf32159 = L.map(
#                 &quot;map_b151517720b90942985302073cf32159&quot;,
#                 {
#                     center: [34.74185761949499, 135.44375197245995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d99dfcdd49b38a379ce2951a4bd6c2a3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b151517720b90942985302073cf32159);
#
#
#             var marker_de68b75efc3db5256ae3f5c7740817c1 = L.marker(
#                 [38.225443683680965, 140.88619132558006],
#                 {}
#             ).addTo(map_b151517720b90942985302073cf32159);
#
#
#         var custom_icon_57934818dcbefda2788de8e90be6a122 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_de68b75efc3db5256ae3f5c7740817c1.setIcon(custom_icon_57934818dcbefda2788de8e90be6a122);
#
#
#         var popup_0ae63d25e142b932fb413b1f89dd307e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_64e0c9b044b032239c0ee55070bd0693 = $(`&lt;div id=&quot;html_64e0c9b044b032239c0ee55070bd0693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 仙台&lt;/div&gt;`)[0];
#             popup_0ae63d25e142b932fb413b1f89dd307e.setContent(html_64e0c9b044b032239c0ee55070bd0693);
#
#
#         marker_de68b75efc3db5256ae3f5c7740817c1.bindPopup(popup_0ae63d25e142b932fb413b1f89dd307e)
#         ;
#
#
#
#
#             var marker_e328f8885652bebdcc23711831312d8b = L.marker(
#                 [35.85624087928599, 139.87055303188004],
#                 {}
#             ).addTo(map_b151517720b90942985302073cf32159);
#
#
#         var custom_icon_95198d0cd8855315aa57801d213692ca = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_e328f8885652bebdcc23711831312d8b.setIcon(custom_icon_95198d0cd8855315aa57801d213692ca);
#
#
#         var popup_f46c34985c76834e2808481412143395 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f32d3bcfbce43058412044eab2e7d30b = $(`&lt;div id=&quot;html_f32d3bcfbce43058412044eab2e7d30b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA 新三郷&lt;/div&gt;`)[0];
#             popup_f46c34985c76834e2808481412143395.setContent(html_f32d3bcfbce43058412044eab2e7d30b);
#
#
#         marker_e328f8885652bebdcc23711831312d8b.bindPopup(popup_f46c34985c76834e2808481412143395)
#         ;
#
#
#
#
#             var marker_6686d8b6defc9779f815587e947e5a79 = L.marker(
#                 [35.681556817882, 139.99198855709005],
#                 {}
#             ).addTo(map_b151517720b90942985302073cf32159);
#
#
#         var custom_icon_913e5580f3a46d07f2960859758203d2 = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_6686d8b6defc9779f815587e947e5a79.setIcon(custom_icon_913e5580f3a46d07f2960859758203d2);
#
#
#         var popup_7b2b2d323b520a3db7136dd8ab5ffaf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d7e34876a5da8321b3dfc599a032fbdc = $(`&lt;div id=&quot;html_d7e34876a5da8321b3dfc599a032fbdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IKEA  Tokyo-Bay&lt;/div&gt;`)[0];
#             popup_7b2b2d323b520a3db7136dd8ab5ffaf1.setContent(html_d7e34876a5da8321b3dfc599a032fbdc);
#
#
#         marker_6686d8b6defc9779f815587e947e5a79.bindPopup(popup_7b2b2d323b520a3db7136dd8ab5ffaf1)
#         ;
#
#
#
#
#             var marker_9bf3a41fe01c17d06b4948e91f78d6d8 = L.marker(
#                 [35.706808311052995, 139.41189273079],
#                 {}
#             ).addTo(map_b151517720b90942985302073cf32159);
#
#
#         var custom_icon_b0a91db10e9208039b206d89dba9a57d = L.icon({&quot;iconAnchor&quot;: [30, 30], &quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3]});
#         marker_9bf3a41fe01c17d06b4948e91f78d6d8.setIcon(custom_icon_b0a91db10e9208039b206d89dba9a57d);
#
#
#         var popup_ecb41df388ac0c0d8a32f0448dcf26e8 = L.popup({&quot;maxW

# %%
map.save("HTML/LALAPORT_Osaka.html")
